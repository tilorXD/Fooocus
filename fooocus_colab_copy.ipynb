# %%
# 1. Instalar dependencias
# !pip install pygit2==1.15.1

# 2. Clonar tu repositorio de Fooocus y entrar al directorio
# %cd /content
# !git clone https://github.com/tilorXD/Fooocus.git
# %cd /content/Fooocus

# %%
# 3. Montar Google Drive
# Se abrirá una ventana para autenticar la cuenta de Google
from google.colab import drive
drive.mount('/content/drive')

# %%
# 4. Copiar Checkpoint y LORAs desde Drive a las carpetas de Fooocus

# --------------------------------------------------------------------------------------
# (Usar 'Sharedwithme' si la carpeta fue compartida, o 'MyDrive' si es tu cuenta principal)
# --------------------------------------------------------------------------------------
DRIVE_CHECKPOINT_PATH = '/content/drive/Sharedwithme/Models/Checkpoints/' # <-- RUTA CHECKPOINT
DRIVE_LORAS_DIR = '/content/drive/Sharedwithme/Models/LORAs/' # <-- RUTA CARPETA LORAs

# Rutas de destino dentro del directorio de Fooocus (NO MODIFICAR ESTAS)
FOOCUS_CHECKPOINTS_DIR = '/content/Fooocus/models/checkpoints/'
FOOCUS_LORAS_DIR = '/content/Fooocus/models/loras/'

# --- Ejecutar Copia de Archivos ---

# 4.1. Copiar el Checkpoint principal
print('Copiando Checkpoint principal...')
# !cp "$DRIVE_CHECKPOINT_PATH" "$FOOCUS_CHECKPOINTS_DIR"

# 4.2. Copiar los LORAs (todos los archivos safetensors y pt)
print('Copiando LORAs...')
# !cp "$DRIVE_LORAS_DIR"/*.safetensors "$FOOCUS_LORAS_DIR"
# !cp "$DRIVE_LORAS_DIR"/*.pt "$FOOCUS_LORAS_DIR"
print('Copia de modelos grandes finalizada.')

# %%
# 5. Ejecutar Fooocus
# !python entry_with_update.py --share --always-high-vram
